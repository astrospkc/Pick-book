# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import pandas as pd

# %%
# prompt: import numpy pandas and pickle

import numpy as np
import pandas as pd
import pickle

# %%
books = pd.read_csv('Books.csv')
ratings = pd.read_csv('Ratings.csv')
users  =pd.read_csv('Users.csv')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_21492\2397436897.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv')

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
# prompt: check null value

print(books.isnull().sum())
print(ratings.isnull().sum())
print(users.isnull().sum())
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
# prompt: check duplicacy

print(books.duplicated().sum())
print(ratings.duplicated().sum())
print(users.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
# prompt: information of books

books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
# @title Popularity based recommendation
# prompt: merge books and ratings data frame on the basis of isbn column

# Popularity based recommendation
merged_data = pd.merge(books, ratings, on='ISBN')
merged_data.head()
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
# 2  0002005018         Clara Callan  Richard Bruce Wright                2001
# 3  0002005018         Clara Callan  Richard Bruce Wright                2001
# 4  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
# ...

# %%
merged_data.groupby(['Book-Title','Book-Author','Image-URL-M']).count()['Book-Rating']
# Out:
# Book-Title                                                                                                  Book-Author                Image-URL-M
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)  Karen Hesse                http://images.amazon.com/images/P/0590567330.01.MZZZZZZZ.jpg    4
#  Always Have Popsicles                                                                                      Rebecca Harvin             http://images.amazon.com/images/P/0964147726.01.MZZZZZZZ.jpg    1
#  Apple Magic (The Collector's series)                                                                       Martina Boudreau           http://images.amazon.com/images/P/0942320093.01.MZZZZZZZ.jpg    1
#  Ask Lily (Young Women of Faith: Lily Series, Book 5)                                                       Nancy N. Rue               http://images.amazon.com/images/P/0310232546.01.MZZZZZZZ.jpg    1
# ...

# %%
# to get the above data in tabular format
num_book_rating = merged_data.groupby(['Book-Title','Book-Author','Image-URL-M']).count()['Book-Rating'].reset_index()
num_book_rating.rename(columns={'Book-Rating':'Num_Book_Rating'}, inplace=True)
num_book_rating
# Out:
#                                                Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of ...
# 1                                   Always Have Popsicles
# 2                    Apple Magic (The Collector's series)
# 3        Ask Lily (Young Women of Faith: Lily Series, ...
# 4        Beyond IBM: Leadership Marketing and Finance ...
# ...                                                   ...
# 269836                                      Ã?Â?lpiraten.
# 269837                     Ã?Â?rger mit Produkt X. Roman.
# 269838                                Ã?Â?sterlich leben.
# 269839                              Ã?Â?stlich der Berge.
# 269840                                  Ã?Â?thique en toc
#
#                       Book-Author  \
# 0                     Karen Hesse
# 1                  Rebecca Harvin
# 2                Martina Boudreau
# 3                    Nancy N. Rue
# 4                      Lou Mobley
# ...                           ...
# ...

# %%
# prompt: avg_book_rating = merged_data.groupby('Book-Title').mean()['Book-Rating'].reset_index()
# avg_book_rating.rename(columns={'Book-Rating':'Avg_Book_Rating'}, inplace=True)
# avg_book_rating , implement this without any error in code

avg_book_rating = merged_data.groupby(['Book-Title','Book-Author','Image-URL-M'])['Book-Rating'].mean().reset_index()
avg_book_rating.rename(columns={'Book-Rating': 'Avg_Book_Rating'}, inplace=True)

avg_book_rating
# Out:
#                                                Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of ...
# 1                                   Always Have Popsicles
# 2                    Apple Magic (The Collector's series)
# 3        Ask Lily (Young Women of Faith: Lily Series, ...
# 4        Beyond IBM: Leadership Marketing and Finance ...
# ...                                                   ...
# 269836                                      Ã?Â?lpiraten.
# 269837                     Ã?Â?rger mit Produkt X. Roman.
# 269838                                Ã?Â?sterlich leben.
# 269839                              Ã?Â?stlich der Berge.
# 269840                                  Ã?Â?thique en toc
#
#                       Book-Author  \
# 0                     Karen Hesse
# 1                  Rebecca Harvin
# 2                Martina Boudreau
# 3                    Nancy N. Rue
# 4                      Lou Mobley
# ...                           ...
# ...

# %%
popular_df_author = num_book_rating.merge(avg_book_rating,on='Book-Author')
popular_df_author
# Out:
#                                               Book-Title_x       Book-Author  \
# 0         A Light in the Storm: The Civil War Diary of ...       Karen Hesse
# 1         A Light in the Storm: The Civil War Diary of ...       Karen Hesse
# 2         A Light in the Storm: The Civil War Diary of ...       Karen Hesse
# 3         A Light in the Storm: The Civil War Diary of ...       Karen Hesse
# 4         A Light in the Storm: The Civil War Diary of ...       Karen Hesse
# ...                                                    ...               ...
# 7033408                                  Ã?Â?thique en toc  Didier Daeninckx
# 7033409                                  Ã?Â?thique en toc  Didier Daeninckx
# 7033410                                  Ã?Â?thique en toc  Didier Daeninckx
# 7033411                                  Ã?Â?thique en toc  Didier Daeninckx
# 7033412                                  Ã?Â?thique en toc  Didier Daeninckx
#
# ...

# %%
# merging average and number of ratings

popular_df = num_book_rating.merge(avg_book_rating,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of ...
# 1                                   Always Have Popsicles
# 2                    Apple Magic (The Collector's series)
# 3        Ask Lily (Young Women of Faith: Lily Series, ...
# 4        Beyond IBM: Leadership Marketing and Finance ...
# ...                                                   ...
# 367220                                      Ã?Â?lpiraten.
# 367221                     Ã?Â?rger mit Produkt X. Roman.
# 367222                                Ã?Â?sterlich leben.
# 367223                              Ã?Â?stlich der Berge.
# 367224                                  Ã?Â?thique en toc
#
#                     Book-Author_x  \
# 0                     Karen Hesse
# 1                  Rebecca Harvin
# 2                Martina Boudreau
# 3                    Nancy N. Rue
# 4                      Lou Mobley
# ...                           ...
# ...

# %%
popular_df_author[popular_df_author['Num_Book_Rating'] >= 250].sort_values('Avg_Book_Rating', ascending=False)
# Out:
#                                               Book-Title_x      Book-Author  \
# 136948                                     A Painted House     John Grisham
# 347477                                       American Gods      Neil Gaiman
# 5944965                                  The Pelican Brief     John Grisham
# 35925                                   A Bend in the Road  Nicholas Sparks
# 6011964                The Red Tent (Bestselling Backlist)    Anita Diamant
# ...                                                    ...              ...
# 3047415  Left Behind: A Novel of the Earth's Last Days ...       Tim Lahaye
# 5982737                                The Prince of Tides       Pat Conroy
# 5982736                                The Prince of Tides       Pat Conroy
# 3047416  Left Behind: A Novel of the Earth's Last Days ...       Tim Lahaye
# 2601308                         Interview with the Vampire        Anne Rice
#
# ...

# %%
# prompt: popular_df[popular_df['Num_Book_Rating']>=250].sort_values('avg_book_rating', ascending=False) , do this code without any error

popular_df[popular_df['Num_Book_Rating'] >= 250].sort_values('Avg_Book_Rating', ascending=False)
# Out:
#                                                Book-Title     Book-Author_x  \
# 355441                                When the Wind Blows   James Patterson
# 316092                            The Secret Life of Bees     Sue Monk Kidd
# 7638                              A Prayer for Owen Meany       John Irving
# 147715                                      Jurassic Park  Michael Crichton
# 299290                                     The Lost World  Michael Crichton
# ...                                                   ...               ...
# 311079  The Queen of the Damned (Vampire Chronicles (P...         Anne Rice
# 189836                                       Mystic River     Dennis Lehane
# 311506                                      The Rainmaker      JOHN GRISHAM
# 58916                                               Congo  Michael Crichton
# 180150  Midnight in the Garden of Good and Evil: A Sav...      John Berendt
#
# ...

# %%
popular_df['Image-URL-M_x'][0]
# Out:
# 'http://images.amazon.com/images/P/0590567330.01.MZZZZZZZ.jpg'

# %%
popular_df
# Out:
#                                                Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of ...
# 1                                   Always Have Popsicles
# 2                    Apple Magic (The Collector's series)
# 3        Ask Lily (Young Women of Faith: Lily Series, ...
# 4        Beyond IBM: Leadership Marketing and Finance ...
# ...                                                   ...
# 367220                                      Ã?Â?lpiraten.
# 367221                     Ã?Â?rger mit Produkt X. Roman.
# 367222                                Ã?Â?sterlich leben.
# 367223                              Ã?Â?stlich der Berge.
# 367224                                  Ã?Â?thique en toc
#
#                     Book-Author_x  \
# 0                     Karen Hesse
# 1                  Rebecca Harvin
# 2                Martina Boudreau
# 3                    Nancy N. Rue
# 4                      Lou Mobley
# ...                           ...
# ...

# %%
popular_df_final_author = pd.merge(popular_df_author[popular_df_author['Num_Book_Rating'] >= 250].sort_values('Avg_Book_Rating', ascending=False), books, on='Book-Title', how='outer')
popular_df_final_author= popular_df_final_author.drop_duplicates('Book-Author')[['Book-Title','Book-Author','Image-URL-M','Avg_Book_Rating','Num_Book_Rating']]
popular_df_final_author

# %%
# prompt: merge popular_df with book on Book-Title omitting duplicates in book title

popular_df_final = pd.merge(popular_df[popular_df['Num_Book_Rating'] >= 250].sort_values('Avg_Book_Rating', ascending=False), books, on='Book-Title', how='outer')
popular_df_final= popular_df_final.drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','Avg_Book_Rating','Num_Book_Rating']]
popular_df_final
# Out:
#                                                Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of ...
# 1                                   Always Have Popsicles
# 2                    Apple Magic (The Collector's series)
# 3        Ask Lily (Young Women of Faith: Lily Series, ...
# 4        Beyond IBM: Leadership Marketing and Finance ...
# ...                                                   ...
# 273119                                      Ã?Â?lpiraten.
# 273120                     Ã?Â?rger mit Produkt X. Roman.
# 273121                                Ã?Â?sterlich leben.
# 273122                              Ã?Â?stlich der Berge.
# 273123                                  Ã?Â?thique en toc
#
#                       Book-Author  \
# 0                     Karen Hesse
# 1                  Rebecca Harvin
# 2                Martina Boudreau
# 3                    Nancy N. Rue
# 4                      Lou Mobley
# ...                           ...
# ...

# %%
# @title collaborative filtering based recommendatio
merged_data
# Out:
#                ISBN                                         Book-Title  \
# 0        0195153448                                Classical Mythology
# 1        0002005018                                       Clara Callan
# 2        0002005018                                       Clara Callan
# 3        0002005018                                       Clara Callan
# 4        0002005018                                       Clara Callan
# ...             ...                                                ...
# 1031131  0440400988                         There's a Bat in Bunk Five
# 1031132  0525447644                            From One to One Hundred
# 1031133  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1031134  0192126040                        Republic (World's Classics)
# 1031135  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author Year-Of-Publication  \
# 0          Mark P. O. Morford                2002
# ...

# %%
# every user id and how many books pers user has rated
x = merged_data.groupby('User-ID').count()['Book-Rating'] >200
# boolean indexing
book_readers = x[x].index

# %%
filtered_rating = merged_data[merged_data['User-ID'].isin(book_readers)]

# %%
y =filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings.drop_duplicates()
# Out:
#                ISBN                       Book-Title      Book-Author  \
# 31       0399135782           The Kitchen God's Wife          Amy Tan
# 33       0399135782           The Kitchen God's Wife          Amy Tan
# 34       0399135782           The Kitchen God's Wife          Amy Tan
# 38       0399135782           The Kitchen God's Wife          Amy Tan
# 39       0399135782           The Kitchen God's Wife          Amy Tan
# ...             ...                              ...              ...
# 1028414  1878702831                           Echoes      Nancy Morse
# 1028600  0394429869  I Know Why the Caged Bird Sings     Maya Angelou
# 1028602  0449001164                      The Promise      CHAIM POTOK
# 1028815  0743527631         The Pillars of the Earth      Ken Follett
# 1028817  0745168086              The Handmaid's Tale  Margaret Atwood
#
#         Year-Of-Publication                      Publisher  \
# 31                     1991               Putnam Pub Group
# ...

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt.fillna(0,inplace = True)
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
# prompt: import cosine similarity

from sklearn.metrics.pairwise import cosine_similarity

similarity_scores = cosine_similarity(pt)
similarity_scores.shape
similarity_scores
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
# recommend system
def recommend(book_name):
  # index fet
  index = np.where(pt.index==book_name)[0][0]
  distances = similarity_scores[index]
  similar_items = sorted(list(enumerate(distances)), key=lambda x:x[1], reverse=True)[1:6]

  data=[]
  for i in similar_items:
    item = []
    temp_df = books[books['Book-Title']==pt.index[i[0]]]
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
    item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
    data.append(item)
  return data
  # return suggestions

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# [['Harry Potter and the Prisoner of Azkaban (Book 3)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Goblet of Fire (Book 4)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Book 1)",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Order of the Phoenix (Book 5)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg']]

# %%
# prompt: # recommend system
# def recommend(book_name):
#   # index fet
#   index = np.where(pt.index=='Zoya')[0][0]
#   distances = similarity_scores[index]
#     print(i[0])
def recommend(book_name):
  # index fet
  index = np.where(pt.index==book_name)[0][0]
  distances = similarity_scores[index]
  similar_items = sorted(list(enumerate(distances)), key=lambda x:x[1], reverse=True)[1:6]

  for i in similar_items:
    print(pt.index[i[0]])
  # return suggestions

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# Harry Potter and the Sorcerer's Stone (Book 1)
# Harry Potter and the Order of the Phoenix (Book 5)

# %%
sorted(list(enumerate(similarity_scores[0])), key=lambda x:x[1], reverse=True)[1:6]
# Out:
# [(47, 0.2702651417103732),
#  (545, 0.2639619371123497),
#  (82, 0.23669374347400993),
#  (634, 0.23299389358170394),
#  (551, 0.2262639743141286)]

# %%
sorted(list(enumerate(similarity_scores[0])), key=lambda x:x[1], reverse=True)[1:6]
# Out:
# [(47, 0.2702651417103732),
#  (545, 0.2639619371123497),
#  (82, 0.23669374347400993),
#  (634, 0.23299389358170394),
#  (551, 0.2262639743141286)]

# %%
# sorted list
sorted(list(enumerate(similarity_scores[0])), key=lambda x:x[1], reverse=True)[1:10]
# Out:
# [(47, 0.2702651417103732),
#  (545, 0.2639619371123497),
#  (82, 0.23669374347400993),
#  (634, 0.23299389358170394),
#  (551, 0.2262639743141286),
#  (181, 0.22222254415660225),
#  (500, 0.21057743765309012),
#  (344, 0.20675540390453995),
#  (554, 0.20025063706783053)]

# %%
pt.index[545]
# Out:
# "The Handmaid's Tale"

# %%
popular_df_final
# Out:
#                                                Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of ...
# 1                                   Always Have Popsicles
# 2                    Apple Magic (The Collector's series)
# 3        Ask Lily (Young Women of Faith: Lily Series, ...
# 4        Beyond IBM: Leadership Marketing and Finance ...
# ...                                                   ...
# 273119                                      Ã?Â?lpiraten.
# 273120                     Ã?Â?rger mit Produkt X. Roman.
# 273121                                Ã?Â?sterlich leben.
# 273122                              Ã?Â?stlich der Berge.
# 273123                                  Ã?Â?thique en toc
#
#                       Book-Author  \
# 0                     Karen Hesse
# 1                  Rebecca Harvin
# 2                Martina Boudreau
# 3                    Nancy N. Rue
# 4                      Lou Mobley
# ...                           ...
# ...

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))
pickle.dump(pt, open('pt.pkl','wb'))
pickle.dump(books, open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
popular_df
# Out:
#                                                Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of ...
# 1                                   Always Have Popsicles
# 2                    Apple Magic (The Collector's series)
# 3        Ask Lily (Young Women of Faith: Lily Series, ...
# 4        Beyond IBM: Leadership Marketing and Finance ...
# ...                                                   ...
# 367220                                      Ã?Â?lpiraten.
# 367221                     Ã?Â?rger mit Produkt X. Roman.
# 367222                                Ã?Â?sterlich leben.
# 367223                              Ã?Â?stlich der Berge.
# 367224                                  Ã?Â?thique en toc
#
#                     Book-Author_x  \
# 0                     Karen Hesse
# 1                  Rebecca Harvin
# 2                Martina Boudreau
# 3                    Nancy N. Rue
# 4                      Lou Mobley
# ...                           ...
# ...

# %%
final_ratings
# Out:
#                ISBN                       Book-Title      Book-Author  \
# 31       0399135782           The Kitchen God's Wife          Amy Tan
# 33       0399135782           The Kitchen God's Wife          Amy Tan
# 34       0399135782           The Kitchen God's Wife          Amy Tan
# 38       0399135782           The Kitchen God's Wife          Amy Tan
# 39       0399135782           The Kitchen God's Wife          Amy Tan
# ...             ...                              ...              ...
# 1028414  1878702831                           Echoes      Nancy Morse
# 1028600  0394429869  I Know Why the Caged Bird Sings     Maya Angelou
# 1028602  0449001164                      The Promise      CHAIM POTOK
# 1028815  0743527631         The Pillars of the Earth      Ken Follett
# 1028817  0745168086              The Handmaid's Tale  Margaret Atwood
#
#         Year-Of-Publication                      Publisher  \
# 31                     1991               Putnam Pub Group
# ...

# %%
popular_df
# Out:
#                                                Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of ...
# 1                                   Always Have Popsicles
# 2                    Apple Magic (The Collector's series)
# 3        Ask Lily (Young Women of Faith: Lily Series, ...
# 4        Beyond IBM: Leadership Marketing and Finance ...
# ...                                                   ...
# 367220                                      Ã?Â?lpiraten.
# 367221                     Ã?Â?rger mit Produkt X. Roman.
# 367222                                Ã?Â?sterlich leben.
# 367223                              Ã?Â?stlich der Berge.
# 367224                                  Ã?Â?thique en toc
#
#                     Book-Author_x  \
# 0                     Karen Hesse
# 1                  Rebecca Harvin
# 2                Martina Boudreau
# 3                    Nancy N. Rue
# 4                      Lou Mobley
# ...                           ...
# ...

# %%
# prompt: get what are the columns present in the final_Rating data

final_ratings.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L', 'User-ID', 'Book-Rating'],
#       dtype='object')

# %%
# Split data into training and testing sets

from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(final_ratings, test_size=0.2, random_state=42)
# Display the shapes of training and testing sets
print("Training set shape:", train_data.shape)
print("Testing set shape:", test_data.shape)
# Out:
# Training set shape: (46868, 10)
# Testing set shape: (11718, 10)

# %%
# train a simple recommendation model and evaluate its performance:

# from surprise import Dataset, Reader, accuracy
# from surprise.model_selection import train_test_split
# from surprise import KNNBasic

# Define a Reader object
# reader = Reader(rating_scale=(1, 5))

# Load the dataset from the DataFrame and specify the rating scale
# data = Dataset.load_from_df(train_data[['User-ID', 'Book-Title', 'Book-Rating']], reader)

# Split the dataset into train and test sets
# trainset, testset = train_test_split(data, test_size=0.2)

# Train a basic collaborative filtering model
# model = KNNBasic(sim_options={'user_based': True})
# model.fit(trainset)

# Make predictions on the test set
# predictions = model.test(testset)

# Evaluate model performance
# accuracy.rmse(predictions)
