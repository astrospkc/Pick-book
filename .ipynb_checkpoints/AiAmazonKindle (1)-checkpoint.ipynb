# %%
# prompt: import numpy pandas and pickle

import numpy as np
import pandas as pd
import pickle

# %%
books = pd.read_csv('Books.csv')
ratings = pd.read_csv('Ratings.csv')
users  =pd.read_csv('Users.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     135     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      94     reply = _read_next_input_message()
#      95     if reply == _NOT_READY or not isinstance(reply, dict):
# ---> 96       time.sleep(0.025)
#      97       continue
#      98     if (
#
# KeyboardInterrupt:

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford               2002.0     Oxford University Press
# 1  Richard Bruce Wright               2001.0       HarperFlamingo Canada
# 2          Carlo D'Este               1991.0             HarperPerennial
# 3      Gina Bari Kolata               1999.0        Farrar Straus Giroux
# 4       E. J. W. Barber               1999.0  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X          0.0
# 1   276726  0155061224          5.0
# 2   276727  0446520802          0.0
# 3   276729  052165615X          3.0
# 4   276729  0521795028          6.0

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (55042, 8)
# (753374, 3)
# (278858, 3)

# %%
# prompt: check null value

print(books.isnull().sum())
print(ratings.isnull().sum())
print(users.isnull().sum())
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    1
# Publisher              1
# Image-URL-S            1
# Image-URL-M            1
# Image-URL-L            1
# dtype: int64
# User-ID        0
# ISBN           0
# Book-Rating    1
# dtype: int64
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
# prompt: check duplicacy

print(books.duplicated().sum())
print(ratings.duplicated().sum())
print(users.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
# prompt: information of books

books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55042 entries, 0 to 55041
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ISBN                 55042 non-null  object
#  1   Book-Title           55042 non-null  object
#  2   Book-Author          55041 non-null  object
#  3   Year-Of-Publication  55041 non-null  float64
#  4   Publisher            55041 non-null  object
#  5   Image-URL-S          55041 non-null  object
#  6   Image-URL-M          55041 non-null  object
#  7   Image-URL-L          55041 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 3.4+ MB

# %%
# @title Popularity based recommendation
# prompt: merge books and ratings data frame on the basis of isbn column

# Popularity based recommendation
merged_data = pd.merge(books, ratings, on='ISBN')
merged_data.head()
# Out:
#          ISBN           Book-Title           Book-Author  Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford               2002.0
# 1  0002005018         Clara Callan  Richard Bruce Wright               2001.0
# 2  0002005018         Clara Callan  Richard Bruce Wright               2001.0
# 3  0002005018         Clara Callan  Richard Bruce Wright               2001.0
# 4  0002005018         Clara Callan  Richard Bruce Wright               2001.0
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L  User-ID  Book-Rating
# 0  http://images.amazon.com/images/P/0195153448.0...        2          0.0
# 1  http://images.amazon.com/images/P/0002005018.0...        8          5.0
# 2  http://images.amazon.com/images/P/0002005018.0...    11400          0.0
# 3  http://images.amazon.com/images/P/0002005018.0...    11676          8.0
# 4  http://images.amazon.com/images/P/0002005018.0...    41385          0.0

# %%
merged_data.groupby('Book-Title').count()['Book-Rating']
# Out:
# Book-Title
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    4
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   1
#  Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth              5
#  Final Fantasy Anthology: Official Strategy Guide (Brady Games)                                               4
#  It Takes Two                                                                                                 2
#                                                                                                              ..
# Â¿QuiÃ©n se ha llevado mi queso?                                                                              1
# Â¿QuÃ© me quieres, amor?                                                                                      6
# Ã?Â?ber die Freiheit.                                                                                         1
# Ã?Â?bermorgen.                                                                                                1
# Ã?Â?thique en toc                                                                                             2
# Name: Book-Rating, Length: 49836, dtype: int64

# %%
# to get the above data in tabular format
num_book_rating = merged_data.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_book_rating.rename(columns={'Book-Rating':'Num_Book_Rating'}, inplace=True)
num_book_rating
# Out:
#                                               Book-Title  Num_Book_Rating
# 0       A Light in the Storm: The Civil War Diary of ...                4
# 1       Beyond IBM: Leadership Marketing and Finance ...                1
# 2       Earth Prayers From around the World: 365 Pray...                5
# 3       Final Fantasy Anthology: Official Strategy Gu...                4
# 4                                           It Takes Two                2
# ...                                                  ...              ...
# 49831                   Â¿QuiÃ©n se ha llevado mi queso?                1
# 49832                           Â¿QuÃ© me quieres, amor?                6
# 49833                              Ã?Â?ber die Freiheit.                1
# 49834                                     Ã?Â?bermorgen.                1
# 49835                                  Ã?Â?thique en toc                2
#
# [49836 rows x 2 columns]

# %%
# prompt: avg_book_rating = merged_data.groupby('Book-Title').mean()['Book-Rating'].reset_index()
# avg_book_rating.rename(columns={'Book-Rating':'Avg_Book_Rating'}, inplace=True)
# avg_book_rating , implement this without any error in code

avg_book_rating = merged_data.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_book_rating.rename(columns={'Book-Rating': 'Avg_Book_Rating'}, inplace=True)

avg_book_rating
# Out:
#                                               Book-Title  Avg_Book_Rating
# 0       A Light in the Storm: The Civil War Diary of ...             2.25
# 1       Beyond IBM: Leadership Marketing and Finance ...             0.00
# 2       Earth Prayers From around the World: 365 Pray...             6.60
# 3       Final Fantasy Anthology: Official Strategy Gu...             5.00
# 4                                           It Takes Two             0.00
# ...                                                  ...              ...
# 49831                   Â¿QuiÃ©n se ha llevado mi queso?             7.00
# 49832                           Â¿QuÃ© me quieres, amor?             2.00
# 49833                              Ã?Â?ber die Freiheit.             7.00
# 49834                                     Ã?Â?bermorgen.             0.00
# 49835                                  Ã?Â?thique en toc             4.00
#
# [49836 rows x 2 columns]

# %%
# merging average and number of ratings

popular_df = num_book_rating.merge(avg_book_rating,on='Book-Title')
popular_df
# Out:
#                                               Book-Title  Num_Book_Rating  \
# 0       A Light in the Storm: The Civil War Diary of ...                4
# 1       Beyond IBM: Leadership Marketing and Finance ...                1
# 2       Earth Prayers From around the World: 365 Pray...                5
# 3       Final Fantasy Anthology: Official Strategy Gu...                4
# 4                                           It Takes Two                2
# ...                                                  ...              ...
# 49831                   Â¿QuiÃ©n se ha llevado mi queso?                1
# 49832                           Â¿QuÃ© me quieres, amor?                6
# 49833                              Ã?Â?ber die Freiheit.                1
# 49834                                     Ã?Â?bermorgen.                1
# 49835                                  Ã?Â?thique en toc                2
#
#        Avg_Book_Rating
# 0                 2.25
# 1                 0.00
# 2                 6.60
# 3                 5.00
# 4                 0.00
# ...                ...
# 49831             7.00
# 49832             2.00
# 49833             7.00
# 49834             0.00
# 49835             4.00
#
# [49836 rows x 3 columns]

# %%
# prompt: popular_df[popular_df['Num_Book_Rating']>=250].sort_values('avg_book_rating', ascending=False) , do this code without any error

popular_df[popular_df['Num_Book_Rating'] >= 250].sort_values('Avg_Book_Rating', ascending=False)
# Out:
#                                               Book-Title  Num_Book_Rating  \
# 16396  Harry Potter and the Prisoner of Azkaban (Book 3)              273
# 16388   Harry Potter and the Chamber of Secrets (Book 2)              377
# 16403  Harry Potter and the Sorcerer's Stone (Harry P...              374
# 45675                              To Kill a Mockingbird              324
# 42932                            The Secret Life of Bees              515
# ...                                                  ...              ...
# 42709                                   The Runaway Jury              316
# 48413                                   While I Was Gone              285
# 39571                                The Horse Whisperer              335
# 48338                                When the Wind Blows              254
# 48712                                        Wild Animus             1628
#
#        Avg_Book_Rating
# 16396         5.641026
# 16388         5.169761
# 16403         5.032086
# 45675         4.743827
# 42932         4.605825
# ...                ...
# 42709         2.724684
# 48413         2.673684
# 39571         2.659701
# 48338         2.606299
# 48712         1.035627
#
# [72 rows x 3 columns]

# %%
# prompt: merge popular_df with book on Book-Title omitting duplicates in book title

popular_df_final = pd.merge(popular_df[popular_df['Num_Book_Rating'] >= 250].sort_values('Avg_Book_Rating', ascending=False), books, on='Book-Title', how='outer')
popular_df_final= popular_df_final.drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','Avg_Book_Rating','Num_Book_Rating']]
popular_df_final
# Out:
#                                               Book-Title         Book-Author  \
# 0      Harry Potter and the Prisoner of Azkaban (Book 3)       J. K. Rowling
# 2       Harry Potter and the Chamber of Secrets (Book 2)       J. K. Rowling
# 5      Harry Potter and the Sorcerer's Stone (Harry P...       J. K. Rowling
# 6                                  To Kill a Mockingbird          Harper Lee
# 9                                The Secret Life of Bees       Sue Monk Kidd
# ...                                                  ...                 ...
# 55037      Historien om Weimar: En kultur i Europas mitt    Folke Schimanski
# 55038  You Eat What You Are: People, Culture and Food...  Thelma Barer-Stein
# 55039  International Jobs : Where They Are, How to Ge...         Eric Kocher
# 55040  Eat That Frog!: 21 Great Ways to Stop Procrast...         Brian Tracy
# 55041  The Claus Family Album: Stories of Santa Claus...                 NaN
#
#                                              Image-URL-M  Avg_Book_Rating  \
# 0      http://images.amazon.com/images/P/0439136350.0...         5.641026
# 2      http://images.amazon.com/images/P/0439064872.0...         5.169761
# 5      http://images.amazon.com/images/P/059035342X.0...         5.032086
# 6      http://images.amazon.com/images/P/0446310786.0...         4.743827
# 9      http://images.amazon.com/images/P/0142001740.0...         4.605825
# ...                                                  ...              ...
# 55037  http://images.amazon.com/images/P/9151831066.0...              NaN
# 55038  http://images.amazon.com/images/P/1552093654.0...              NaN
# 55039  http://images.amazon.com/images/P/0738200395.0...              NaN
# 55040  http://images.amazon.com/images/P/1576751988.0...              NaN
# 55041                                                NaN              NaN
#
#        Num_Book_Rating
# 0                273.0
# 2                377.0
# 5                374.0
# 6                324.0
# 9                515.0
# ...                ...
# 55037              NaN
# 55038              NaN
# 55039              NaN
# 55040              NaN
# 55041              NaN
#
# [50763 rows x 5 columns]

# %%
# @title collaborative filtering based recommendatio
merged_data
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0002005018                                       Clara Callan
# 3       0002005018                                       Clara Callan
# 4       0002005018                                       Clara Callan
# ...            ...                                                ...
# 405462  9151831066      Historien om Weimar: En kultur i Europas mitt
# 405463  0738200395  International Jobs : Where They Are, How to Ge...
# 405464  1576751988  Eat That Frog!: 21 Great Ways to Stop Procrast...
# 405465  1576751988  Eat That Frog!: 21 Great Ways to Stop Procrast...
# 405466  1576466450  The Claus Family Album: Stories of Santa Claus...
#
#                  Book-Author  Year-Of-Publication                   Publisher  \
# 0         Mark P. O. Morford               2002.0     Oxford University Press
# 1       Richard Bruce Wright               2001.0       HarperFlamingo Canada
# 2       Richard Bruce Wright               2001.0       HarperFlamingo Canada
# 3       Richard Bruce Wright               2001.0       HarperFlamingo Canada
# 4       Richard Bruce Wright               2001.0       HarperFlamingo Canada
# ...                      ...                  ...                         ...
# 405462      Folke Schimanski               1998.0         RabÃ©n &amp; Prisma
# 405463           Eric Kocher               1999.0         Perseus Books Group
# 405464           Brian Tracy               2002.0  Berrett-Koehler Publishers
# 405465           Brian Tracy               2002.0  Berrett-Koehler Publishers
# 405466                   NaN                  NaN                         NaN
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0002005018.0...
# 3       http://images.amazon.com/images/P/0002005018.0...
# 4       http://images.amazon.com/images/P/0002005018.0...
# ...                                                   ...
# 405462  http://images.amazon.com/images/P/9151831066.0...
# 405463  http://images.amazon.com/images/P/0738200395.0...
# 405464  http://images.amazon.com/images/P/1576751988.0...
# 405465  http://images.amazon.com/images/P/1576751988.0...
# 405466                                                NaN
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0002005018.0...
# 3       http://images.amazon.com/images/P/0002005018.0...
# 4       http://images.amazon.com/images/P/0002005018.0...
# ...                                                   ...
# 405462  http://images.amazon.com/images/P/9151831066.0...
# 405463  http://images.amazon.com/images/P/0738200395.0...
# 405464  http://images.amazon.com/images/P/1576751988.0...
# 405465  http://images.amazon.com/images/P/1576751988.0...
# 405466                                                NaN
#
#                                               Image-URL-L  User-ID  \
# 0       http://images.amazon.com/images/P/0195153448.0...        2
# 1       http://images.amazon.com/images/P/0002005018.0...        8
# 2       http://images.amazon.com/images/P/0002005018.0...    11400
# 3       http://images.amazon.com/images/P/0002005018.0...    11676
# 4       http://images.amazon.com/images/P/0002005018.0...    41385
# ...                                                   ...      ...
# 405462  http://images.amazon.com/images/P/9151831066.0...    29238
# 405463  http://images.amazon.com/images/P/0738200395.0...   106816
# 405464  http://images.amazon.com/images/P/1576751988.0...    97179
# 405465  http://images.amazon.com/images/P/1576751988.0...   173579
# 405466                                                NaN   170229
#
#         Book-Rating
# 0               0.0
# 1               5.0
# 2               0.0
# 3               8.0
# 4               0.0
# ...             ...
# 405462          0.0
# 405463          0.0
# 405464          7.0
# 405465          0.0
# 405466          0.0
#
# [405467 rows x 10 columns]

# %%
# every user id and how many books pers user has rated
x = merged_data.groupby('User-ID').count()['Book-Rating'] >200
# boolean indexing
book_readers = x[x].index

# %%
filtered_rating = merged_data[merged_data['User-ID'].isin(book_readers)]

# %%
y =filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index
famous_books
# Out:
# Index(['1st to Die: A Novel', '2nd Chance', 'A Bend in the Road',
#        'A Is for Alibi (Kinsey Millhone Mysteries (Paperback))',
#        'A Map of the World', 'A Painted House', 'A Prayer for Owen Meany',
#        'A Time to Kill', 'A Walk to Remember', 'A Widow for One Year',
#        ...
#        'We Were the Mulvaneys', 'Welcome to the World, Baby Girl!',
#        'When the Wind Blows',
#        'Where the Heart Is (Oprah's Book Club (Paperback))',
#        'While I Was Gone', 'Whispers', 'White Oleander : A Novel',
#        'White Oleander : A Novel (Oprah's Book Club)',
#        'Wicked: The Life and Times of the Wicked Witch of the West',
#        'Wild Animus'],
#       dtype='object', name='Book-Title', length=164)

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings.drop_duplicates()
# Out:
#               ISBN                               Book-Title   Book-Author  \
# 23      0399135782                   The Kitchen God's Wife       Amy Tan
# 25      0399135782                   The Kitchen God's Wife       Amy Tan
# 26      0399135782                   The Kitchen God's Wife       Amy Tan
# 30      0399135782                   The Kitchen God's Wife       Amy Tan
# 31      0399135782                   The Kitchen God's Wife       Amy Tan
# ...            ...                                      ...           ...
# 400520  0140278826  The Girls' Guide to Hunting and Fishing  Melissa Bank
# 400537  0140278826  The Girls' Guide to Hunting and Fishing  Melissa Bank
# 404197  0375701524                The Hundred Secret Senses       Amy Tan
# 404204  0375701524                The Hundred Secret Senses       Amy Tan
# 404205  0375701524                The Hundred Secret Senses       Amy Tan
#
#         Year-Of-Publication          Publisher  \
# 23                   1991.0   Putnam Pub Group
# 25                   1991.0   Putnam Pub Group
# 26                   1991.0   Putnam Pub Group
# 30                   1991.0   Putnam Pub Group
# 31                   1991.0   Putnam Pub Group
# ...                     ...                ...
# 400520               2000.0  Penguin Books Ltd
# 400537               2000.0  Penguin Books Ltd
# 404197               1998.0  Vintage Books USA
# 404204               1998.0  Vintage Books USA
# 404205               1998.0  Vintage Books USA
#
#                                               Image-URL-S  \
# 23      http://images.amazon.com/images/P/0399135782.0...
# 25      http://images.amazon.com/images/P/0399135782.0...
# 26      http://images.amazon.com/images/P/0399135782.0...
# 30      http://images.amazon.com/images/P/0399135782.0...
# 31      http://images.amazon.com/images/P/0399135782.0...
# ...                                                   ...
# 400520  http://images.amazon.com/images/P/0140278826.0...
# 400537  http://images.amazon.com/images/P/0140278826.0...
# 404197  http://images.amazon.com/images/P/0375701524.0...
# 404204  http://images.amazon.com/images/P/0375701524.0...
# 404205  http://images.amazon.com/images/P/0375701524.0...
#
#                                               Image-URL-M  \
# 23      http://images.amazon.com/images/P/0399135782.0...
# 25      http://images.amazon.com/images/P/0399135782.0...
# 26      http://images.amazon.com/images/P/0399135782.0...
# 30      http://images.amazon.com/images/P/0399135782.0...
# 31      http://images.amazon.com/images/P/0399135782.0...
# ...                                                   ...
# 400520  http://images.amazon.com/images/P/0140278826.0...
# 400537  http://images.amazon.com/images/P/0140278826.0...
# 404197  http://images.amazon.com/images/P/0375701524.0...
# 404204  http://images.amazon.com/images/P/0375701524.0...
# 404205  http://images.amazon.com/images/P/0375701524.0...
#
#                                               Image-URL-L  User-ID  \
# 23      http://images.amazon.com/images/P/0399135782.0...    11676
# 25      http://images.amazon.com/images/P/0399135782.0...    36836
# 26      http://images.amazon.com/images/P/0399135782.0...    46398
# 30      http://images.amazon.com/images/P/0399135782.0...   113270
# 31      http://images.amazon.com/images/P/0399135782.0...   113519
# ...                                                   ...      ...
# 400520  http://images.amazon.com/images/P/0140278826.0...    11676
# 400537  http://images.amazon.com/images/P/0140278826.0...   175003
# 404197  http://images.amazon.com/images/P/0375701524.0...    35859
# 404204  http://images.amazon.com/images/P/0375701524.0...   165308
# 404205  http://images.amazon.com/images/P/0375701524.0...   173415
#
#         Book-Rating
# 23              9.0
# 25              0.0
# 26              9.0
# 30              0.0
# 31              0.0
# ...             ...
# 400520          8.0
# 400537          0.0
# 404197          0.0
# 404204          0.0
# 404205          0.0
#
# [11130 rows x 10 columns]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     7.0
# A Map of the World                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Whispers                                               NaN     NaN     NaN
# White Oleander : A Novel                               0.0     NaN     NaN
# White Oleander : A Novel (Oprah's Book Club)           NaN     NaN     0.0
# Wicked: The Life and Times of the Wicked Witch ...     NaN     NaN     NaN
# Wild Animus                                            NaN     NaN     6.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     NaN
# A Map of the World                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Whispers                                               NaN     NaN     NaN
# White Oleander : A Novel                               7.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           NaN     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     NaN     0.0     NaN
# Wild Animus                                            0.0     0.0     NaN
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     NaN
# A Map of the World                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Whispers                                               NaN     NaN     NaN
# White Oleander : A Novel                               NaN     8.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           NaN     0.0     NaN
# Wicked: The Life and Times of the Wicked Witch ...     NaN     0.0     NaN
# Wild Animus                                            NaN     0.0     NaN
#
# User-ID                                             6543    ...  177072  \
# Book-Title                                                  ...
# 1st to Die: A Novel                                    9.0  ...     NaN
# 2nd Chance                                             0.0  ...     9.0
# A Bend in the Road                                     NaN  ...     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN  ...     NaN
# A Map of the World                                     NaN  ...     NaN
# ...                                                    ...  ...     ...
# Whispers                                               NaN  ...     NaN
# White Oleander : A Novel                               NaN  ...     NaN
# White Oleander : A Novel (Oprah's Book Club)           NaN  ...     NaN
# Wicked: The Life and Times of the Wicked Witch ...    10.0  ...     0.0
# Wild Animus                                            0.0  ...     NaN
#
# User-ID                                             177090  177458  178667  \
# Book-Title
# 1st to Die: A Novel                                    NaN     7.0     NaN
# 2nd Chance                                             NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     NaN
# A Map of the World                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Whispers                                               NaN     NaN     NaN
# White Oleander : A Novel                               NaN     NaN     NaN
# White Oleander : A Novel (Oprah's Book Club)           8.0     NaN     NaN
# Wicked: The Life and Times of the Wicked Witch ...     0.0     NaN     NaN
# Wild Animus                                            0.0     0.0     NaN
#
# User-ID                                             179733  180651  181176  \
# Book-Title
# 1st to Die: A Novel                                    NaN     7.0     NaN
# 2nd Chance                                             NaN     0.0     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     0.0
# A Map of the World                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Whispers                                               NaN     NaN     0.0
# White Oleander : A Novel                               NaN     0.0     NaN
# White Oleander : A Novel (Oprah's Book Club)           NaN     NaN     0.0
# Wicked: The Life and Times of the Wicked Witch ...     NaN     NaN     0.0
# Wild Animus                                            0.0     NaN     0.0
#
# User-ID                                             182085  277427  278418
# Book-Title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     NaN
# A Map of the World                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Whispers                                               NaN     NaN     NaN
# White Oleander : A Novel                               NaN     0.0     NaN
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     NaN
# Wicked: The Life and Times of the Wicked Witch ...     NaN     NaN     NaN
# Wild Animus                                            0.0     0.0     NaN
#
# [164 rows x 290 columns]

# %%
pt.fillna(0,inplace = True)
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     7.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Whispers                                               0.0     0.0     0.0
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     6.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Whispers                                               0.0     0.0     0.0
# White Oleander : A Novel                               7.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Whispers                                               0.0     0.0     0.0
# White Oleander : A Novel                               0.0     8.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# User-ID                                             6543    ...  177072  \
# Book-Title                                                  ...
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     9.0
# A Bend in the Road                                     0.0  ...     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0  ...     0.0
# A Map of the World                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Whispers                                               0.0  ...     0.0
# White Oleander : A Novel                               0.0  ...     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0  ...     0.0
# Wicked: The Life and Times of the Wicked Witch ...    10.0  ...     0.0
# Wild Animus                                            0.0  ...     0.0
#
# User-ID                                             177090  177458  178667  \
# Book-Title
# 1st to Die: A Novel                                    0.0     7.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Whispers                                               0.0     0.0     0.0
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           8.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# User-ID                                             179733  180651  181176  \
# Book-Title
# 1st to Die: A Novel                                    0.0     7.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Whispers                                               0.0     0.0     0.0
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# User-ID                                             182085  277427  278418
# Book-Title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Whispers                                               0.0     0.0     0.0
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# [164 rows x 290 columns]

# %%
# prompt: import cosine similarity

from sklearn.metrics.pairwise import cosine_similarity

similarity_scores = cosine_similarity(pt)
similarity_scores.shape
# Out:
# (164, 164)

# %%
# recommend system
def recommend(book_name):
  # index fet
  index = np.where(pt.index=='Zoya')[0][0]
  distances = similarity_scores[index]
  similar_items = sorted(list(enumerate(similarity_scores[0])), key=lambda x:x[1], reverse=True)[1:6]

  for i in similar_items:
    print(i[0])
  # return suggestions

# %%
# prompt: # recommend system
# def recommend(book_name):
#   # index fet
#   index = np.where(pt.index=='Zoya')[0][0]
#   distances = similarity_scores[index]
#     print(i[0])
def recommend(book_name):
  # index fet
  index = np.where(pt.index==book_name)[0][0]
  distances = similarity_scores[index]
  similar_items = sorted(list(enumerate(distances)), key=lambda x:x[1], reverse=True)[1:6]

  for i in similar_items:
    print(pt.index[i[0]])
  # return suggestions

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# The Alienist
# A Time to Kill

# %%
sorted(list(enumerate(similarity_scores[0])), key=lambda x:x[1], reverse=True)[1:6]
# Out:
# [(72, 0.41738705933481046),
#  (146, 0.3561311535465015),
#  (11, 0.3543135976937558),
#  (48, 0.3428423010161281),
#  (152, 0.329395633682724)]

# %%
sorted(list(enumerate(similarity_scores[0])), key=lambda x:x[1], reverse=True)[1:6]
# Out:
# [(72, 0.41738705933481046),
#  (146, 0.3561311535465015),
#  (11, 0.3543135976937558),
#  (48, 0.3428423010161281),
#  (152, 0.329395633682724)]

# %%
# sorted list
sorted(list(enumerate(similarity_scores[0])), key=lambda x:x[1], reverse=True)[1:10]
# Out:
# [(72, 0.41738705933481046),
#  (146, 0.3561311535465015),
#  (11, 0.3543135976937558),
#  (48, 0.3428423010161281),
#  (152, 0.329395633682724)]

# %%
final_ratings
# Out:
#               ISBN                               Book-Title   Book-Author  \
# 23      0399135782                   The Kitchen God's Wife       Amy Tan
# 25      0399135782                   The Kitchen God's Wife       Amy Tan
# 26      0399135782                   The Kitchen God's Wife       Amy Tan
# 30      0399135782                   The Kitchen God's Wife       Amy Tan
# 31      0399135782                   The Kitchen God's Wife       Amy Tan
# ...            ...                                      ...           ...
# 400520  0140278826  The Girls' Guide to Hunting and Fishing  Melissa Bank
# 400537  0140278826  The Girls' Guide to Hunting and Fishing  Melissa Bank
# 404197  0375701524                The Hundred Secret Senses       Amy Tan
# 404204  0375701524                The Hundred Secret Senses       Amy Tan
# 404205  0375701524                The Hundred Secret Senses       Amy Tan
#
#         Year-Of-Publication          Publisher  \
# 23                   1991.0   Putnam Pub Group
# 25                   1991.0   Putnam Pub Group
# 26                   1991.0   Putnam Pub Group
# 30                   1991.0   Putnam Pub Group
# 31                   1991.0   Putnam Pub Group
# ...                     ...                ...
# 400520               2000.0  Penguin Books Ltd
# 400537               2000.0  Penguin Books Ltd
# 404197               1998.0  Vintage Books USA
# 404204               1998.0  Vintage Books USA
# 404205               1998.0  Vintage Books USA
#
#                                               Image-URL-S  \
# 23      http://images.amazon.com/images/P/0399135782.0...
# 25      http://images.amazon.com/images/P/0399135782.0...
# 26      http://images.amazon.com/images/P/0399135782.0...
# 30      http://images.amazon.com/images/P/0399135782.0...
# 31      http://images.amazon.com/images/P/0399135782.0...
# ...                                                   ...
# 400520  http://images.amazon.com/images/P/0140278826.0...
# 400537  http://images.amazon.com/images/P/0140278826.0...
# 404197  http://images.amazon.com/images/P/0375701524.0...
# 404204  http://images.amazon.com/images/P/0375701524.0...
# 404205  http://images.amazon.com/images/P/0375701524.0...
#
#                                               Image-URL-M  \
# 23      http://images.amazon.com/images/P/0399135782.0...
# 25      http://images.amazon.com/images/P/0399135782.0...
# 26      http://images.amazon.com/images/P/0399135782.0...
# 30      http://images.amazon.com/images/P/0399135782.0...
# 31      http://images.amazon.com/images/P/0399135782.0...
# ...                                                   ...
# 400520  http://images.amazon.com/images/P/0140278826.0...
# 400537  http://images.amazon.com/images/P/0140278826.0...
# 404197  http://images.amazon.com/images/P/0375701524.0...
# 404204  http://images.amazon.com/images/P/0375701524.0...
# 404205  http://images.amazon.com/images/P/0375701524.0...
#
#                                               Image-URL-L  User-ID  \
# 23      http://images.amazon.com/images/P/0399135782.0...    11676
# 25      http://images.amazon.com/images/P/0399135782.0...    36836
# 26      http://images.amazon.com/images/P/0399135782.0...    46398
# 30      http://images.amazon.com/images/P/0399135782.0...   113270
# 31      http://images.amazon.com/images/P/0399135782.0...   113519
# ...                                                   ...      ...
# 400520  http://images.amazon.com/images/P/0140278826.0...    11676
# 400537  http://images.amazon.com/images/P/0140278826.0...   175003
# 404197  http://images.amazon.com/images/P/0375701524.0...    35859
# 404204  http://images.amazon.com/images/P/0375701524.0...   165308
# 404205  http://images.amazon.com/images/P/0375701524.0...   173415
#
#         Book-Rating
# 23              9.0
# 25              0.0
# 26              9.0
# 30              0.0
# 31              0.0
# ...             ...
# 400520          8.0
# 400537          0.0
# 404197          0.0
# 404204          0.0
# 404205          0.0
#
# [11130 rows x 10 columns]

# %%
# prompt: get what are the columns present in the final_Rating data

final_ratings.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L', 'User-ID', 'Book-Rating'],
#       dtype='object')

# %%
# Split data into training and testing sets

from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(final_ratings, test_size=0.2, random_state=42)
# Display the shapes of training and testing sets
print("Training set shape:", train_data.shape)
print("Testing set shape:", test_data.shape)
# Out:
# Training set shape: (8904, 10)
# Testing set shape: (2226, 10)

# %%
# train a simple recommendation model and evaluate its performance:

from surprise import Dataset, Reader, accuracy
from surprise.model_selection import train_test_split
from surprise import KNNBasic

# Define a Reader object
reader = Reader(rating_scale=(1, 5))

# Load the dataset from the DataFrame and specify the rating scale
data = Dataset.load_from_df(train_data[['User-ID', 'Book-Title', 'Book-Rating']], reader)

# Split the dataset into train and test sets
trainset, testset = train_test_split(data, test_size=0.2)

# Train a basic collaborative filtering model
model = KNNBasic(sim_options={'user_based': True})
model.fit(trainset)

# Make predictions on the test set
predictions = model.test(testset)

# Evaluate model performance
accuracy.rmse(predictions)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-82-38cbe259cd51> in <cell line: 3>()
#       1 # train a simple recommendation model and evaluate its performance:
#       2
# ----> 3 from surprise import Dataset, Reader, accuracy
#       4 from surprise.model_selection import train_test_split
#       5 from surprise import KNNBasic
#
# ModuleNotFoundError: No module named 'surprise'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
